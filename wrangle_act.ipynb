# %% [markdown]
# ## 1- Importing Libraries

# %%
import pandas as pd
import numpy as np
import requests
import matplotlib.pyplot as plt
# %matplotlib inline
import tweepy
from tweepy import OAuthHandler
import json
from timeit import default_timer as timer
from IPython.display import Image
import urllib.request

# %% [markdown]
# ## 2- Data Gathering

# %% [markdown]
# ### a- Twitter Archive (csv)

# %%
t_archive = pd.read_csv('twitter-archive-enhanced.csv')

# %% [markdown]
# ### b- Image prediction (tsv)

# %%
url = 'https://d17h27t6h515a5.cloudfront.net/topher/2017/August/599fd2ad_image-predictions/image-predictions.tsv'
response =requests.get(url)

with open('image_predictions.tsv', 'wb') as file:
    file.write(response.content)

i_predictions= pd.read_csv('image_predictions.tsv', sep= "\t")

# %% [markdown]
# ### c- Twitter API

# %%
consumer_key = 'Enter your consumerKey'
consumer_secret = 'Enter your consumer secret'
access_token = 'Enter your access token'
access_secret = 'Enter your access secret'

auth = OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)
api = tweepy.API(auth, wait_on_rate_limit = True)

tweet_ids = t_archive.tweet_id.values
count= 0
fails_dict={}
start=timer()
with open ('tweet_json.txt','w') as outfile:
    for tweet_id in tweet_ids[:2356]: 
        count +=1
        print(str(count) + ": " +str(tweet_id))
        try:
            tweet= api.get_status(tweet_id, tweet_mode="extended")
            print("Success")
            json.dump(tweet._json, outfile)
            outfile.write("\n")
        except tweepy.TweepError as e:
            print("Fail")
            fails_dict[tweet_id]=e
            pass
           
end=timer()
print(end-start)
print(fails_dict)
# Out:
# 1: 892420643555336193
# Success
# 2: 892177421306343426
# Success
# 3: 891815181378084864
# Success
# 4: 891689557279858688
# Success
# 5: 891327558926688256
# Success
# 6: 891087950875897856
# Success
# 7: 890971913173991426
# Success
# 8: 890729181411237888
# Success
# 9: 890609185150312448
# Success
# 10: 890240255349198849
# Success
# 11: 890006608113172480
# Success
# 12: 889880896479866881
# Success
# 13: 889665388333682689
# Success
# 14: 889638837579907072
# Success
# 15: 889531135344209921
# Success
# 16: 889278841981685760
# Success
# 17: 888917238123831296
# Success
# 18: 888804989199671297
# Success
# 19: 888554962724278272
# Success
# 20: 888202515573088257
# Fail
# 21: 888078434458587136
# Success
# 22: 887705289381826560
# Success
# 23: 887517139158093824
# Success
# 24: 887473957103951883
# Success
# 25: 887343217045368832
# Success
# 26: 887101392804085760
# Success
# 27: 886983233522544640
# Success
# 28: 886736880519319552
# Success
# 29: 886680336477933568
# ...

# %% [markdown]
# ### d- Tweet-Json

# %%
df_list= []
with open ('tweet_json.txt') as file:
    for line in file:
        df_list.append(json.loads(line))
#Creating DataFrame using json file
tweet_data= pd.DataFrame(df_list, columns= ['id', 'retweet_count', 'favorite_count'])
tweet_data = tweet_data.rename(columns= {'id': 'tweet_id'})
#Saving tweet_data Data frame as csv file
tweet_data.to_csv('tweet_data.csv', index=False)
#checking Csv file
x= pd.read_csv('tweet_data.csv')
x.head()
# Out:
#              tweet_id  retweet_count  favorite_count
# 0  892420643555336193           7373           35070
# 1  892177421306343426           5494           30365
# 2  891815181378084864           3632           22827
# 3  891689557279858688           7551           38346
# 4  891327558926688256           8138           36621

# %% [markdown]
# ## 3- Data Assessing
# ### a- Twtitter Archive

# %%
t_archive.head(15)
# Out:
#               tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0   892420643555336193                    NaN                  NaN
# 1   892177421306343426                    NaN                  NaN
# 2   891815181378084864                    NaN                  NaN
# 3   891689557279858688                    NaN                  NaN
# 4   891327558926688256                    NaN                  NaN
# 5   891087950875897856                    NaN                  NaN
# 6   890971913173991426                    NaN                  NaN
# 7   890729181411237888                    NaN                  NaN
# 8   890609185150312448                    NaN                  NaN
# 9   890240255349198849                    NaN                  NaN
# 10  890006608113172480                    NaN                  NaN
# 11  889880896479866881                    NaN                  NaN
# 12  889665388333682689                    NaN                  NaN
# ...

# %%
t_archive.tail(7)
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 2349  666051853826850816                    NaN                  NaN
# 2350  666050758794694657                    NaN                  NaN
# 2351  666049248165822465                    NaN                  NaN
# 2352  666044226329800704                    NaN                  NaN
# 2353  666033412701032449                    NaN                  NaN
# 2354  666029285002620928                    NaN                  NaN
# 2355  666020888022790149                    NaN                  NaN
#
#                       timestamp  \
# 2349  2015-11-16 00:35:11 +0000
# 2350  2015-11-16 00:30:50 +0000
# 2351  2015-11-16 00:24:50 +0000
# 2352  2015-11-16 00:04:52 +0000
# 2353  2015-11-15 23:21:54 +0000
# 2354  2015-11-15 23:05:30 +0000
# 2355  2015-11-15 22:32:08 +0000
#
#                                                  source  \
# 2349  <a href="http://twitter.com/download/iphone" r...
# ...

# %%
t_archive.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   tweet_id                    2356 non-null   int64
#  1   in_reply_to_status_id       78 non-null     float64
#  2   in_reply_to_user_id         78 non-null     float64
#  3   timestamp                   2356 non-null   object
#  4   source                      2356 non-null   object
#  5   text                        2356 non-null   object
#  6   retweeted_status_id         181 non-null    float64
#  7   retweeted_status_user_id    181 non-null    float64
#  8   retweeted_status_timestamp  181 non-null    object
#  9   expanded_urls               2297 non-null   object
#  10  rating_numerator            2356 non-null   int64
#  11  rating_denominator          2356 non-null   int64
#  12  name                        2356 non-null   object
# ...

# %%
t_archive.rating_numerator.describe()
#The rating should start by 10 min!!
# Out:
# count    2356.000000
# mean       13.126486
# std        45.876648
# min         0.000000
# 25%        10.000000
# 50%        11.000000
# 75%        12.000000
# max      1776.000000
# Name: rating_numerator, dtype: float64

# %%
# Checking how many ratings less than 10
t_archive[t_archive.rating_numerator <10].count()[0]
# Out:
# 440

# %%
#showing the id
t_archive[t_archive.rating_numerator <10].tweet_id
# Out:
# 45      883482846933004288
# 229     848212111729840128
# 315     835152434251116546
# 387     826598799820865537
# 462     817502432452313088
#                ...
# 2351    666049248165822465
# 2352    666044226329800704
# 2353    666033412701032449
# 2354    666029285002620928
# 2355    666020888022790149
# Name: tweet_id, Length: 440, dtype: int64

# %%
#checking on tweet
t_archive.loc[2351,'text']
# Out:
# 'Here we have a 1949 1st generation vulpix. Enjoys sweat tea and Fox News. Cannot be phased. 5/10 https://t.co/4B7cOc1EDq'

# %%
t_archive.rating_denominator.describe()
#All data should be 10!
# Out:
# count    2356.000000
# mean       10.455433
# std         6.745237
# min         0.000000
# 25%        10.000000
# 50%        10.000000
# 75%        10.000000
# max       170.000000
# Name: rating_denominator, dtype: float64

# %%
# Checking tweets with 0 denominator
t_archive[t_archive.rating_denominator == 0].tweet_id
# Out:
# 313    835246439529840640
# Name: tweet_id, dtype: int64

# %%
t_archive.loc[313,'text']
# Out:
# "@jonnysun @Lin_Manuel ok jomny I know you're excited but 960/00 isn't a valid rating, 13/10 is tho"

# %% [markdown]
# ### b- Tweet image predictions

# %%
i_predictions.sample(7)
# Out:
#                 tweet_id                                          jpg_url  \
# 1968  868552278524837888  https://pbs.twimg.com/media/DA23sCeVoAE3uF0.jpg
# 411   673906403526995968  https://pbs.twimg.com/media/CVoySqoWUAAWb7N.jpg
# 841   694905863685980160  https://pbs.twimg.com/media/CaTNMUgUYAAB6vs.jpg
# 603   679844490799091713  https://pbs.twimg.com/media/CW9K9VeVAAE0j-x.jpg
# 1123  727175381690781696  https://pbs.twimg.com/media/ChdyJvdWwAA5HGd.jpg
# 2045  886366144734445568  https://pbs.twimg.com/media/DE0BTnQUwAApKEH.jpg
# 1773  828011680017821696  https://pbs.twimg.com/media/C32wOLcWYAAjNqS.jpg
#
#       img_num                              p1   p1_conf  p1_dog  \
# 1968        1                         whippet  0.378151    True
# 411         1                     toilet_seat  0.683319   False
# 841         1                         bow_tie  0.449268   False
# 603         1                        Airedale  0.903832    True
# ...

# %%
# Checking random image :D

# %%
url2=i_predictions.loc[777,'jpg_url']
Image(url2)
#cool image <3

# %%
urllib.request.urlretrieve(url2,'Cool_photo.png')
# Out:
# ('Cool_photo.png', <http.client.HTTPMessage at 0x2379f2767f0>)

# %%
i_predictions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075 entries, 0 to 2074
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   tweet_id  2075 non-null   int64
#  1   jpg_url   2075 non-null   object
#  2   img_num   2075 non-null   int64
#  3   p1        2075 non-null   object
#  4   p1_conf   2075 non-null   float64
#  5   p1_dog    2075 non-null   bool
#  6   p2        2075 non-null   object
#  7   p2_conf   2075 non-null   float64
#  8   p2_dog    2075 non-null   bool
#  9   p3        2075 non-null   object
#  10  p3_conf   2075 non-null   float64
#  11  p3_dog    2075 non-null   bool
# dtypes: bool(3), float64(3), int64(2), object(4)
# memory usage: 152.1+ KB

# %% [markdown]
# ### c- API

# %%
tweet_data.sample(7)
# Out:
#                 tweet_id  retweet_count  favorite_count
# 764   775350846108426240           3805            9944
# 365   827600520311402496            910            7311
# 284   837110210464448512           2267           15585
# 2091  670427002554466305            146             487
# 769   773985732834758656           3752           10516
# 1568  686394059078897668            660            1678
# 1836  675483430902214656            905            1737

# %%
tweet_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2331 entries, 0 to 2330
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tweet_id        2331 non-null   int64
#  1   retweet_count   2331 non-null   int64
#  2   favorite_count  2331 non-null   int64
# dtypes: int64(3)
# memory usage: 54.8 KB

# %% [markdown]
# ## Assesment Notes
# ### Tidiness:
# 1- Dog stage data are on 4 columns
#
# 2- Data are splitted into multiple data frames
# ### Quality
# 1- In Twitter archive Retweet data are not required
#
# 2- In Twitter archive some dog names are mistaken
#
# 3- In Twitter archive Tweet_id type should be string instead of int
#
# 4- In Twitter archive Timestamp type should be datetime instead of string
#
# 5- In Twitter archive Some rating nomerator is less than 10
#
# 6- In Twitter archive record 313 denominator is == 0
#
# 7- In Twitter archive some rating dominator are not equal 10
#
# 8- In image prediction some IDs photos are missing
#
# 9- In image prediction underscores are used instead of spaces
#
# 10- In image prediction all name should be started by upppercase letter
#
# 11- Time stamp format is not proper
#
# 12- two columns for rating
#
# 13- Unnecessary columns are existing
#
# 14- Columns are not ordered properly

# %% [markdown]
# ## 4- Data Cleaning
# ### a- Tidiness of Data
# #### 1- Dog stage data are on 4 columns

# %%
#Creating a copies
t_archive_clean = t_archive.copy()
i_predictions_clean=i_predictions.copy()
tweet_data_clean=tweet_data.copy()
t_archive_clean.head(1)
i_predictions_clean.head(1)
tweet_data_clean.head(1)
# Out:
#              tweet_id  retweet_count  favorite_count
# 0  892420643555336193           7373           35070

# %% [markdown]
# ##### Define
# Merge the 4 columns into 1 coulumn
# ##### Code

# %%
t_archive_clean['dog_stage']=t_archive_clean['text'].str.extract('(doggo|floofer|pupper|puppo)')
t_archive_clean.dog_stage.value_counts()
t_archive_clean.drop(columns=['doggo', 'floofer', 'pupper', 'puppo'], inplace=True)

# %% [markdown]
# ##### Test

# %%
t_archive_clean.info()
#done
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 14 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   tweet_id                    2356 non-null   int64
#  1   in_reply_to_status_id       78 non-null     float64
#  2   in_reply_to_user_id         78 non-null     float64
#  3   timestamp                   2356 non-null   object
#  4   source                      2356 non-null   object
#  5   text                        2356 non-null   object
#  6   retweeted_status_id         181 non-null    float64
#  7   retweeted_status_user_id    181 non-null    float64
#  8   retweeted_status_timestamp  181 non-null    object
#  9   expanded_urls               2297 non-null   object
#  10  rating_numerator            2356 non-null   int64
#  11  rating_denominator          2356 non-null   int64
#  12  name                        2356 non-null   object
# ...

# %% [markdown]
# #### 2- Data are splitted into multiple data frames
# ##### Define
# Merge all dataframes into one
# ##### Code

# %%
# left Merge t_archive with tweet_data
t_archive_clean = pd.merge(t_archive_clean, tweet_data_clean, on='tweet_id',how='left')
# left Merge Merged t_archive with i_predictions
t_archive_clean = pd.merge(t_archive_clean, i_predictions_clean, on='tweet_id', how='left')

# %% [markdown]
# ##### Test

# %%
t_archive_clean.info()
#done
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2356 entries, 0 to 2355
# Data columns (total 27 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   tweet_id                    2356 non-null   int64
#  1   in_reply_to_status_id       78 non-null     float64
#  2   in_reply_to_user_id         78 non-null     float64
#  3   timestamp                   2356 non-null   object
#  4   source                      2356 non-null   object
#  5   text                        2356 non-null   object
#  6   retweeted_status_id         181 non-null    float64
#  7   retweeted_status_user_id    181 non-null    float64
#  8   retweeted_status_timestamp  181 non-null    object
#  9   expanded_urls               2297 non-null   object
#  10  rating_numerator            2356 non-null   int64
#  11  rating_denominator          2356 non-null   int64
#  12  name                        2356 non-null   object
# ...

# %% [markdown]
# ### a- Quality of Data
# #### 1- In Twitter archive Retweet data are not required
# ##### Define
# Delete all retweet data
# ##### Code

# %%
# deleting retweet records
t_archive_clean = t_archive_clean[t_archive_clean.retweeted_status_id.isnull()]
# deleting retweet columns
t_archive_clean.drop(columns=['retweeted_status_id', 'retweeted_status_user_id', 'retweeted_status_timestamp' ], inplace=True)

# %% [markdown]
# ##### Test

# %%
t_archive_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2175 entries, 0 to 2355
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   tweet_id               2175 non-null   int64
#  1   in_reply_to_status_id  78 non-null     float64
#  2   in_reply_to_user_id    78 non-null     float64
#  3   timestamp              2175 non-null   object
#  4   source                 2175 non-null   object
#  5   text                   2175 non-null   object
#  6   expanded_urls          2117 non-null   object
#  7   rating_numerator       2175 non-null   int64
#  8   rating_denominator     2175 non-null   int64
#  9   name                   2175 non-null   object
#  10  dog_stage              364 non-null    object
#  11  retweet_count          2168 non-null   float64
#  12  favorite_count         2168 non-null   float64
#  13  jpg_url                1994 non-null   object
# ...

# %% [markdown]
# #### 2- In Twitter archive some dog names are mistaken
# ##### Define
# Extract the correct names from the text column for these records
# ##### Code

# %%
t_archive_clean.name.isnull().sum()
# Out:
# 0

# %%
# Replacing all names that starts with lower case or None by NAN
t_archive_clean.name = t_archive_clean.name.replace(regex=['^[a-z]+','None'], value=np.nan)
# Testing
t_archive_clean.name.isnull().sum()
# Out:
# 784

# %%
def extractor(text):
    """ This function is to extract the word comes after "named", it takes text as argument"""
    text_list = text.split()
    for word in text_list:
        if word.lower() == 'named':
            i = text_list.index(word) + 1
            return text_list[i]
        else: 
            pass
    return np.nan

# %%
t_archive_clean.name = np.where(t_archive_clean.name.isnull(), t_archive_clean.text.apply(extractor), t_archive_clean.name)

# %% [markdown]
# ##### Test

# %%
t_archive_clean.name.isnull().sum()
# Not All were covered :("
# Out:
# 761

# %% [markdown]
# #### 3- In Twitter archive Tweet_id type should be string instead of int
# ##### Define
# Convert tweet_id to str
# ##### Code

# %%
t_archive_clean.tweet_id = t_archive_clean.tweet_id.astype(str)

# %% [markdown]
# ##### Test

# %%
t_archive_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2175 entries, 0 to 2355
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   tweet_id               2175 non-null   object
#  1   in_reply_to_status_id  78 non-null     float64
#  2   in_reply_to_user_id    78 non-null     float64
#  3   timestamp              2175 non-null   object
#  4   source                 2175 non-null   object
#  5   text                   2175 non-null   object
#  6   expanded_urls          2117 non-null   object
#  7   rating_numerator       2175 non-null   int64
#  8   rating_denominator     2175 non-null   int64
#  9   name                   1414 non-null   object
#  10  dog_stage              364 non-null    object
#  11  retweet_count          2168 non-null   float64
#  12  favorite_count         2168 non-null   float64
#  13  jpg_url                1994 non-null   object
# ...

# %% [markdown]
# #### 4- In Twitter archive Timestamp type should be datetime instead of string
# ##### Define
# Convert timestamp to datetime
# ##### Code

# %%
t_archive_clean.timestamp = pd.to_datetime(t_archive_clean.timestamp)

# %% [markdown]
# ##### Test

# %%
t_archive_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2175 entries, 0 to 2355
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   tweet_id               2175 non-null   object
#  1   in_reply_to_status_id  78 non-null     float64
#  2   in_reply_to_user_id    78 non-null     float64
#  3   timestamp              2175 non-null   datetime64[ns, UTC]
#  4   source                 2175 non-null   object
#  5   text                   2175 non-null   object
#  6   expanded_urls          2117 non-null   object
#  7   rating_numerator       2175 non-null   int64
#  8   rating_denominator     2175 non-null   int64
#  9   name                   1414 non-null   object
#  10  dog_stage              364 non-null    object
#  11  retweet_count          2168 non-null   float64
#  12  favorite_count         2168 non-null   float64
#  13  jpg_url                1994 non-null   object
# ...

# %% [markdown]
# #### 8- In image prediction some IDs photos are missing
# ##### Define
# Keeping only records with photos
# ##### Code

# %%
t_archive_clean = t_archive_clean[t_archive_clean.jpg_url.notnull()]

# %% [markdown]
# ##### Test

# %%
t_archive_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1994 entries, 0 to 2355
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   tweet_id               1994 non-null   object
#  1   in_reply_to_status_id  23 non-null     float64
#  2   in_reply_to_user_id    23 non-null     float64
#  3   timestamp              1994 non-null   datetime64[ns, UTC]
#  4   source                 1994 non-null   object
#  5   text                   1994 non-null   object
#  6   expanded_urls          1994 non-null   object
#  7   rating_numerator       1994 non-null   int64
#  8   rating_denominator     1994 non-null   int64
#  9   name                   1373 non-null   object
#  10  dog_stage              326 non-null    object
#  11  retweet_count          1987 non-null   float64
#  12  favorite_count         1987 non-null   float64
#  13  jpg_url                1994 non-null   object
# ...

# %% [markdown]
# #### 9- In image prediction underscores are used instead of spaces
# ##### Define
# replace any underscores by space
# ##### Code

# %%
t_archive_clean.p1 = t_archive_clean.p1.str.replace('_',' ')
t_archive_clean.p2 = t_archive_clean.p2.str.replace('_',' ')
t_archive_clean.p3 = t_archive_clean.p3.str.replace('_',' ')

# %% [markdown]
# ##### Test

# %%
t_archive_clean.p1.sample(7)
# Out:
# 2166    golden retriever
# 2261        electric fan
# 1988            Pembroke
# 2026           bee eater
# 531     golden retriever
# 364     golden retriever
# 2146          car mirror
# Name: p1, dtype: object

# %%
t_archive_clean.p2.sample(7)
# Out:
# 2304         chain saw
# 1334             quilt
# 1745        hair slide
# 859         toy poodle
# 1254    Dandie Dinmont
# 1199         seat belt
# 2151      studio couch
# Name: p2, dtype: object

# %%
t_archive_clean.p3.sample(7)
# Out:
# 388          cougar
# 588     toy terrier
# 1203          cairn
# 114          beagle
# 66         Cardigan
# 2071          dingo
# 1418     sunglasses
# Name: p3, dtype: object

# %% [markdown]
# #### 10- In image prediction all name should be started by upppercase letter
# ##### Define
# Make all names proper
# ##### Code

# %%
t_archive_clean.p1 = t_archive_clean.p1.str.title()
t_archive_clean.p2 = t_archive_clean.p2.str.title()
t_archive_clean.p3 = t_archive_clean.p3.str.title()

# %% [markdown]
# ##### Test

# %%
t_archive_clean.p1.sample(7)
# Out:
# 1867           Pembroke
# 1454            Basenji
# 775          Rottweiler
# 2237             Angora
# 972                 Pug
# 650     Jack-O'-Lantern
# 1403            Samoyed
# Name: p1, dtype: object

# %%
t_archive_clean.p2.sample(7)
# Out:
# 1981              Rhinoceros Beetle
# 1049    Soft-Coated Wheaten Terrier
# 1975                     Pomeranian
# 56                           Angora
# 1035                       Shih-Tzu
# 1402                 French Bulldog
# 1052                       Sunglass
# Name: p2, dtype: object

# %%
t_archive_clean.p3.sample(7)
# Out:
# 2329                 Briard
# 1188                  Chime
# 339                     Pug
# 929          Shower Curtain
# 50                 Cardigan
# 844     Rhodesian Ridgeback
# 178                Keeshond
# Name: p3, dtype: object

# %% [markdown]
# #### 11- Time stamp format is not proper
# ##### Define
# Make 2 columns one for date abd the other for time
# ##### Code

# %%
t_archive_clean['date'] = t_archive_clean['timestamp'].apply(lambda time: time.strftime('%m-%d-%Y'))
t_archive_clean['time'] = t_archive_clean['timestamp'].apply(lambda time: time.strftime('%H:%M'))

# %% [markdown]
# ##### Test

# %%
t_archive_clean['date'].sample(2)
# Out:
# 1053    06-13-2016
# 2230    11-22-2015
# Name: date, dtype: object

# %%
t_archive_clean['time'].sample(2)
# Out:
# 796     19:52
# 2242    03:44
# Name: time, dtype: object

# %%
t_archive_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1994 entries, 0 to 2355
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   tweet_id               1994 non-null   object
#  1   in_reply_to_status_id  23 non-null     float64
#  2   in_reply_to_user_id    23 non-null     float64
#  3   timestamp              1994 non-null   datetime64[ns, UTC]
#  4   source                 1994 non-null   object
#  5   text                   1994 non-null   object
#  6   expanded_urls          1994 non-null   object
#  7   rating_numerator       1994 non-null   int64
#  8   rating_denominator     1994 non-null   int64
#  9   name                   1373 non-null   object
#  10  dog_stage              326 non-null    object
#  11  retweet_count          1987 non-null   float64
#  12  favorite_count         1987 non-null   float64
#  13  jpg_url                1994 non-null   object
# ...

# %% [markdown]
# #### 5- In Twitter archive Some rating nomerator is less than 10
# ##### Define
# Replace any nomerator less than 10 with forward fill
# ##### Code

# %%
# Replacing any nominator less than 10 with NAN
t_archive_clean.loc[t_archive_clean['rating_numerator'] < 10, 'rating_numerator'] = np.nan
# Checking how many nun
len(t_archive_clean.rating_numerator) - t_archive_clean.rating_numerator.count()
#fill nan
t_archive_clean.rating_numerator.fillna(method='ffill', axis=0,inplace=True)

# %% [markdown]
# ##### Test

# %%
len(t_archive_clean.rating_numerator) - t_archive_clean.rating_numerator.count()
# Out:
# 0

# %% [markdown]
# #### 6- In Twitter archive record 313 denominator is == 0
# #### 7- In Twitter archive some rating dominator are not equal 10
# ##### Define
# Replace any dominator not equal to 10 with 10
# ##### Code

# %%
t_archive_clean.loc[t_archive_clean['rating_denominator'] != 10, 'rating_denominator'] = 10

# %% [markdown]
# ##### Test

# %%
t_archive_clean.rating_denominator.unique()
# Out:
# array([10], dtype=int64)

# %% [markdown]
# #### 12- two columns for rating
# ##### Define
# Merge the two columns of ratings together
# ##### Code

# %%
t_archive_clean['rate']=t_archive_clean['rating_numerator'].astype(str)+"/"+t_archive_clean['rating_denominator'].astype(str)

# %% [markdown]
# ##### Test

# %%
t_archive_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1994 entries, 0 to 2355
# Data columns (total 27 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   tweet_id               1994 non-null   object
#  1   in_reply_to_status_id  23 non-null     float64
#  2   in_reply_to_user_id    23 non-null     float64
#  3   timestamp              1994 non-null   datetime64[ns, UTC]
#  4   source                 1994 non-null   object
#  5   text                   1994 non-null   object
#  6   expanded_urls          1994 non-null   object
#  7   rating_numerator       1994 non-null   float64
#  8   rating_denominator     1994 non-null   int64
#  9   name                   1373 non-null   object
#  10  dog_stage              326 non-null    object
#  11  retweet_count          1987 non-null   float64
#  12  favorite_count         1987 non-null   float64
#  13  jpg_url                1994 non-null   object
# ...

# %% [markdown]
# #### 13- Unnecessary columns are existing
# ##### Define
# Delete unnecessary columns
# ##### Code

# %%
t_archive_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1994 entries, 0 to 2355
# Data columns (total 27 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   tweet_id               1994 non-null   object
#  1   in_reply_to_status_id  23 non-null     float64
#  2   in_reply_to_user_id    23 non-null     float64
#  3   timestamp              1994 non-null   datetime64[ns, UTC]
#  4   source                 1994 non-null   object
#  5   text                   1994 non-null   object
#  6   expanded_urls          1994 non-null   object
#  7   rating_numerator       1994 non-null   float64
#  8   rating_denominator     1994 non-null   int64
#  9   name                   1373 non-null   object
#  10  dog_stage              326 non-null    object
#  11  retweet_count          1987 non-null   float64
#  12  favorite_count         1987 non-null   float64
#  13  jpg_url                1994 non-null   object
# ...

# %%
t_archive_clean.drop(['in_reply_to_status_id',
                      'in_reply_to_user_id',
                      'source',
                      'expanded_urls',
                      'rating_denominator',
                      'p1_conf',
                      'p1_dog',
                      'p2_conf',
                      'p2_dog',
                      'p3_conf',
                      'p3_dog',
                      'img_num',
                      'timestamp'
                     ],axis=1, inplace=True)

# %% [markdown]
# ##### Test

# %%
t_archive_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1994 entries, 0 to 2355
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   tweet_id          1994 non-null   object
#  1   text              1994 non-null   object
#  2   rating_numerator  1994 non-null   float64
#  3   name              1373 non-null   object
#  4   dog_stage         326 non-null    object
#  5   retweet_count     1987 non-null   float64
#  6   favorite_count    1987 non-null   float64
#  7   jpg_url           1994 non-null   object
#  8   p1                1994 non-null   object
#  9   p2                1994 non-null   object
#  10  p3                1994 non-null   object
#  11  date              1994 non-null   object
#  12  time              1994 non-null   object
#  13  rate              1994 non-null   object
# dtypes: float64(3), object(11)
# memory usage: 233.7+ KB

# %%
t_archive_clean.sample(7)
# Out:
#                 tweet_id                                               text  \
# 1099  735991953473572864  This is Maxaroni. He's curly af. Also rather f...
# 578   800751577355128832  Say hello to Mauve and Murphy. They're rather ...
# 1889  674774481756377088  This is Superpup. His head isn't proportional ...
# 166   859924526012018688  Meet Milky. She has no idea what happened. Jus...
# 1068  740373189193256964  After so many requests, this is Bretagne. She ...
# 1184  718631497683582976  We normally don't rate marshmallows but this o...
# 1954  673656262056419329  This is Albert AKA King Banana Peel. He's a ki...
#
#       rating_numerator      name dog_stage  retweet_count  favorite_count  \
# 1099              11.0  Maxaroni       NaN         1095.0          3447.0
# 578               12.0     Mauve       NaN         2749.0         10454.0
# 1889              11.0  Superpup    pupper          435.0          1035.0
# ...

# %% [markdown]
# #### 14- Columns are not ordered properly
# ##### Define
# Reorder columns
# ##### Code

# %%
order = ['tweet_id',
         'name',
         'date',
         'time',
         'dog_stage',
         'rating_numerator',
         'rate',
         'retweet_count',
         'favorite_count',
         'p1',
         'p2',
         'p3',
         'text',
         'jpg_url'
        ]
t_archive_clean= t_archive_clean.reindex(columns=order)

# %% [markdown]
# ##### Test

# %% [markdown]
# ## 6- Saving Data

# %%
t_archive_clean.to_csv('twitter_archive_master.csv')

# %% [markdown]
# ## 6- Data Analysis and Visualization

# %%
t_archive_clean.describe()
# Out:
#        rating_numerator  retweet_count  favorite_count
# count       1994.000000    1987.000000     1987.000000
# mean          13.245236    2355.423251     8014.609461
# std           41.783958    4214.891534    11804.821350
# min           10.000000      11.000000       69.000000
# 25%           10.000000     527.500000     1717.000000
# 50%           11.000000    1139.000000     3625.000000
# 75%           12.000000    2680.500000     9946.000000
# max         1776.000000   74434.000000   150808.000000

# %%
#Who is the winning Dog
t_archive_clean[t_archive_clean['rating_numerator']==1776].text.iloc[0]
# Out:
# "This is Atticus. He's quite simply America af. 1776/10 https://t.co/GRXwMxLBkh"

# %%
url3 = t_archive_clean.loc[t_archive_clean['rating_numerator'] == 1776, 'jpg_url'].iloc[0]
Image(url3)

# %%
urllib.request.urlretrieve(url3,'winning_dog.png')  #saving image
t_archive_clean.loc[t_archive_clean['rating_numerator'] == 1776, 'date'].iloc[0]
# Out:
# '07-04-2016'

# %% [markdown]
# #### a- Percentage of Different Dog Stages

# %%
stages = t_archive_clean.dog_stage.value_counts()

# %%
plt.pie(stages, 
        labels= ['Pupper', 'Doggo', 'Puppo', 'Floofer'],
        autopct = '%1.1f%%',
        shadow=True,
        explode=(0.1, 0.2, 0.2, 0.3)      
       )
plt.title('Dog Stages Percent')
plt.axis('equal')
plt.savefig('Dog_stages.png')

# %% [markdown]
# ##### Insights
# Pupper has the highest share while floofer has the lowest

# %% [markdown]
# #### b- Relation between retweet counts and favorite count

# %%
plt.scatter(t_archive_clean.retweet_count, t_archive_clean.favorite_count)
plt.title('Relation between Retweet counts Vs Favorite counts')
plt.xlabel('Retweet Count')
plt.ylabel('Favorite Count')
plt.savefig('retweets_Vs_favorites.png')

# %% [markdown]
# ##### Insights
# There are linear proportional Relationship between retweet counts and favorite counts

# %% [markdown]
# #### c- Dog_rating Frequency

# %%
t_archive_clean['rating_numerator'].plot(kind='hist',bins=range(1,16),figsize=(6,8))
plt.xlabel('Dog Rating')
plt.xlim([2, 30])
plt.title('Most Frequent rating')
plt.savefig('Rating_Frequency.png')

# %% [markdown]
# ##### Insights
# The most frequent ratings are between 10 and 15

# %% [markdown]
# #### e- Top 10 breeds

# %%
dog_stage_p2 = t_archive_clean['p2'].value_counts()

# %%
dog_stage_p2.head(10).plot(x= dog_stage_p2.index , y= dog_stage_p2, kind='bar')
plt.xlabel("Dog Breeds", fontsize=18)
plt.ylabel("Dog Breeds Frequencies", fontsize=18)
plt.title('Top 10 Dog Breeds', fontsize=18)
plt.savefig('Dog_breeds.png')

# %% [markdown]
# ##### Insights
# Labrador Retriever is the most frequent dog breed followed by Golden Retriever and Cardigan
